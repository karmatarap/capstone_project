# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Collecting soundfile
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Collecting pysoundfile
#   Downloading PySoundFile-0.9.0.post1-py2.py3-none-any.whl (24 kB)
# Collecting fastai
#   Downloading fastai-2.5.1-py3-none-any.whl (188 kB)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (2.26.0)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting requests_html==0.10.0
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-0.2.6-py3-none-any.whl (83 kB)
# Requirement already satisfied: w3lib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests_html==0.10.0->-r ./requirements.txt (line 10)) (1.22.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: decorator>=3.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (5.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (1.19.5)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Collecting numba>=0.43.0
#   Downloading numba-0.53.1-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (21.0)
# Requirement already satisfied: joblib>=0.14 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (1.0.1)
# Collecting pooch>=1.0
#   Downloading pooch-1.4.0-py3-none-any.whl (51 kB)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Requirement already satisfied: scipy>=1.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (1.7.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa->-r ./requirements.txt (line 3)) (0.24.2)
# Requirement already satisfied: cffi>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from soundfile->-r ./requirements.txt (line 4)) (1.14.6)
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: pillow>6.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (1.2.5)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading fastcore-1.3.26-py3-none-any.whl (56 kB)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: spacy<4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: torch<1.10,>=1.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: pyyaml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (5.4.1)
# Requirement already satisfied: pip in /root/venv/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (21.2.2)
# Requirement already satisfied: torchvision>=0.8.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fastai->-r ./requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->-r ./requirements.txt (line 7)) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->-r ./requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->-r ./requirements.txt (line 7)) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->-r ./requirements.txt (line 7)) (1.26.6)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 9)) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 9)) (7.26.0)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 9)) (5.1.3)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0->soundfile->-r ./requirements.txt (line 4)) (2.20)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: jupyter-client<7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (6.1)
# Requirement already satisfied: importlib-metadata<4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (3.10.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (3.10.0.0)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (3.0.19)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (57.4.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.17.2)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (2.9.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (4.8.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 9)) (22.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->-r ./requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->-r ./requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r ./requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r ./requirements.txt (line 9)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r ./requirements.txt (line 9)) (21.2.0)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging>=20.0->librosa->-r ./requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.7.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->-r ./requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 10)) (4.62.0)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<10.0,>=9.1
#   Downloading websockets-9.1-cp37-cp37m-manylinux2010_x86_64.whl (103 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->-r ./requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (8.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (3.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (0.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<4->fastai->-r ./requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<4->fastai->-r ./requirements.txt (line 6)) (5.1.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy<4->fastai->-r ./requirements.txt (line 6)) (7.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (7.0.0.dev0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.10.1)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: nbconvert in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->spacy<4->fastai->-r ./requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->fastai->-r ./requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->fastai->-r ./requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (1.4.3)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.5.0)
# Requirement already satisfied: async-generator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (1.10)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r ./requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->fastai->-r ./requirements.txt (line 6)) (2021.1)
# Requirement already satisfied: lxml>=2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 10)) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 10)) (1.1.0)
# Building wheels for collected packages: audioread, resampy, bs4, fake-useragent, parse
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23153 sha256=d9c60246fa3e786a4a58abc73e88209c827e5dfc728f6daf95b4e78e95172f16
#   Stored in directory: /root/.cache/pip/wheels/ba/7b/eb/213741ccc0678f63e346ab8dff10495995ca3f426af87b8d88
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320732 sha256=ef04691279ce3e094c8d4ec50305b8dc840956318dfd3537146ccc31b11106f8
#   Stored in directory: /root/.cache/pip/wheels/a0/18/0a/8ad18a597d8333a142c9789338a96a6208f1198d290ece356c
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=e447f4b5198251c2d406231214d1b39d2c38ae40901c85de413f091e218e4046
#   Stored in directory: /root/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13503 sha256=9c9ecf716cf17217ddb5eb20099b76085b0e5c37d2c3b710a04ab6de95f1b18f
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=7f6046693c6396f90ee320f067560c6aafad16723568f56fe673a9edb27da856
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built audioread resampy bs4 fake-useragent parse
# Installing collected packages: soupsieve, llvmlite, websockets, pyee, numba, fastprogress, fastcore, beautifulsoup4, appdirs, widgetsnbextension, soundfile, resampy, pyquery, pyppeteer, pooch, parse, jupyterlab-widgets, fastdownload, fake-useragent, et-xmlfile, bs4, audioread, xlrd, requests-html, pysoundfile, openpyxl, librosa, ipywidgets, fastai
# Successfully installed appdirs-1.4.4 audioread-2.1.9 beautifulsoup4-4.9.3 bs4-0.0.1 et-xmlfile-1.1.0 fake-useragent-0.1.11 fastai-2.5.1 fastcore-1.3.26 fastdownload-0.0.5 fastprogress-1.0.0 ipywidgets-7.6.3 jupyterlab-widgets-1.0.0 librosa-0.8.1 llvmlite-0.36.0 numba-0.53.1 openpyxl-3.0.7 parse-1.19.0 pooch-1.4.0 pyee-8.2.2 pyppeteer-0.2.6 pyquery-1.4.3 pysoundfile-0.9.0.post1 requests-html-0.10.0 resampy-0.2.2 soundfile-0.10.3.post1 soupsieve-2.2.1 websockets-9.1 widgetsnbextension-3.5.1 xlrd-2.0.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7aa10abb-09ba-4e5c-b109-d1b9cd39afe4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
