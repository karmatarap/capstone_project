# %%
import librosa
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_908/1121779986.py in <module>
# ----> 1 import librosa
#
# ~/venv/lib/python3.7/site-packages/librosa/__init__.py in <module>
#     209 # And all the librosa sub-modules
#     210 from ._cache import cache
# --> 211 from . import core
#     212 from . import beat
#     213 from . import decompose
#
# ~/venv/lib/python3.7/site-packages/librosa/core/__init__.py in <module>
#       4
#       5 from .convert import *  # pylint: disable=wildcard-import
# ----> 6 from .audio import *  # pylint: disable=wildcard-import
#       7 from .spectrum import *  # pylint: disable=wildcard-import
#       8 from .pitch import *  # pylint: disable=wildcard-import
#
# ~/venv/lib/python3.7/site-packages/librosa/core/audio.py in <module>
#       6 import warnings
#       7
# ----> 8 import soundfile as sf
#       9 import audioread
# ...

# %%
# !ls /datasets/dzanga-bai/dzanga-bai/raw_wav
# Out:
# opp_328_ro.wav	      opp_509_ru4.wav	    opp_700_ru.wav
# opp_329_ro.wav	      opp_509_ru5.wav	    opp_701_ru.wav
# opp_330_ru.wav	      opp_509_ru6.wav	    opp_702_ru.wav
# opp_331_ro.wav	      opp_509_ru.wav	    opp_703_ro1.wav
# opp_332_ru.wav	      opp_510_ro.wav	    opp_703_ro2.wav
# opp_333_ru1.wav       opp_511_ro.wav	    opp_703_ro3.wav
# opp_333_ru2.wav       opp_511_ru1.wav	    opp_704_ro.wav
# opp_333_ru.wav	      opp_511_ru2.wav	    opp_705_ru.wav
# opp_334_ru.wav	      opp_511_ru.wav	    opp_706_ro.wav
# opp_335_ru.wav	      opp_512_ro.wav	    opp_707_ru.wav
# opp_336_ru.wav	      opp_513_ro.wav	    opp_708_ru.wav
# opp_337_ro.wav	      opp_514_ru1.wav	    opp_709_ro.wav
# opp_337_ru.wav	      opp_514_ru.wav	    opp_710_ru1.wav
# opp_338_ru.wav	      opp_515_ro.wav	    opp_710_ru2.wav
# opp_339_ro.wav	      opp_515_ru.wav	    opp_711_ro.wav
# opp_339_ru.wav	      opp_516_ro.wav	    opp_712_ru.wav
# opp_340_ro1.wav       opp_517_ru.wav	    opp_713_ro.wav
# ...

# %%
ex = '/datasets/dzanga-bai/dzanga-bai/raw_wav/opp_497_ro.wav'
y, sr = librosa.load(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_908/1991268532.py in <module>
#       1 ex = '/datasets/dzanga-bai/dzanga-bai/raw_wav/opp_497_ro.wav'
# ----> 2 y, sr = librosa.load(ex)
#
# NameError: name 'librosa' is not defined

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7aa10abb-09ba-4e5c-b109-d1b9cd39afe4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
